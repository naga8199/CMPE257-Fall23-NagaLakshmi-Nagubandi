# %% [markdown]
# <a href="https://colab.research.google.com/github/naga8199/CMPE257-Fall23-NagaLakshmi-Nagubandi/blob/class-activities/257_PLA_POCKET.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv("/content/synthetic_dataset.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   x1      50 non-null     float64
#  1   x2      50 non-null     float64
#  2   y       50 non-null     int64
# dtypes: float64(2), int64(1)
# memory usage: 1.3 KB

# %%
df.head(5)
# Out:
#          x1        x2  y
# 0 -4.641770  5.558556  1
# 1  7.139793  6.571105  1
# 2  4.127969 -9.024912 -1
# 3  0.081377  3.861381  1
# 4 -1.253937  8.009625  1
